# %%
url_base= 'https://api.spotify.com/v1'

# %%
ep_artist = '/artists/{artist_id}'

# %%
id_paulo = '3vQ0GE3mI0dAaxIMYe5g7z'

# %%
url = url_base+ep_artist.format(artist_id=id_paulo)
url
# Out:
# 'https://api.spotify.com/v1/artists/3vQ0GE3mI0dAaxIMYe5g7z'

# %%
import requests

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 401

# %%
r.json()
# Out:
# {'error': {'message': 'No token provided', 'status': 401}}

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type':'client_credentials'}

# %%
headers = {'Authorization': 'Basic OTQzMjQ2ODFkMjBiNDAxOWE1YTBiYTliNWQ0YWVjNzk6MDUzYTQyZGRjNzcwNDY0YjhhMDQ2YmQyMTA5NTQwNmU='} #Strind codificado, ClientID:ClientSecret

# %%
r = requests.post(token_url, data=params, headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'access_token': 'BQAdQgpj1t50iON5jL7JHXtZStxRhGqorxO5YVTheWmxuuawL8UQWzCf07LfPEgbpnzqPZxl9_pE8ZCfyOQ',
#  'expires_in': 3600,
#  'scope': '',
#  'token_type': 'Bearer'}

# %%
token = r.json()['access_token']
token
# Out:
# 'BQAdQgpj1t50iON5jL7JHXtZStxRhGqorxO5YVTheWmxuuawL8UQWzCf07LfPEgbpnzqPZxl9_pE8ZCfyOQ'

# %%
header = {'Authorization': 'Bearer {}'.format(token)}

# %%
r = requests.get(url_base+ep_artist.format(artist_id=id_paulo), headers=header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3vQ0GE3mI0dAaxIMYe5g7z'},
#  'followers': {'href': None, 'total': 10033448},
#  'genres': ['argentine hip hop', 'trap argentino', 'trap latino'],
#  'href': 'https://api.spotify.com/v1/artists/3vQ0GE3mI0dAaxIMYe5g7z',
#  'id': '3vQ0GE3mI0dAaxIMYe5g7z',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/cff7f6bb72fd3d318a98557b3891cae1b438c695',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/eac2d4babbdcda19e65083104dd8c64734d1e1ad',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/d6be11bb1a6470faafdea860c3d415a0f4fe34a2',
#    'width': 160}],
#  'name': 'Paulo Londra',
#  'popularity': 80,
#  'type': 'artist',
#  'uri': 'spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z'}

# %%
url_busqueda = 'https://api.spotify.com/v1/search'

# %%
search_params ={'q':'Paulo+londra','type':'artist','market':'AR'}

# %%
busqueda = requests.get(url_busqueda, headers=header, params=search_params)

# %%
busqueda.status_code
# Out:
# 200

# %%
busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Paulo%2Blondra&type=artist&market=AR&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3vQ0GE3mI0dAaxIMYe5g7z'},
#     'followers': {'href': None, 'total': 10033448},
#     'genres': ['argentine hip hop', 'trap argentino', 'trap latino'],
#     'href': 'https://api.spotify.com/v1/artists/3vQ0GE3mI0dAaxIMYe5g7z',
#     'id': '3vQ0GE3mI0dAaxIMYe5g7z',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/cff7f6bb72fd3d318a98557b3891cae1b438c695',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/eac2d4babbdcda19e65083104dd8c64734d1e1ad',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/d6be11bb1a6470faafdea860c3d415a0f4fe34a2',
#       'width': 160}],
#     'name': 'Paulo Londra',
#     'popularity': 80,
#     'type': 'artist',
#     'uri': 'spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 1}}

# %%
import pandas as pd

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])

# %%
df.head(5)
# Out:
#                                        external_urls  ...                                    uri
# 0  {'spotify': 'https://open.spotify.com/artist/3...  ...  spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z
#
# [1 rows x 10 columns]

# %%
df.sort_values(by='popularity', ascending=False) #ordenando de mayor a menos
# Out:
#                                        external_urls  ...                                    uri
# 0  {'spotify': 'https://open.spotify.com/artist/3...  ...  spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z
#
# [1 rows x 10 columns]

# %%
df.sort_values(by='popularity', ascending=False).iloc[0]['id']
# Out:
# '3vQ0GE3mI0dAaxIMYe5g7z'

# %%
import base64

# %%
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes(client_id+':'+client_secret, 'utf-8'))
    params = {'grant_type':'client_credentials'}
    header = {'Authorization': 'Basic ' + str(encoded, 'utf-8')}
    r = requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None
    print('Token válido por {} segundos.'.format(r.json()['expires_in']))
    return r.json()['access_token']

# %%
client_id = '94324681d20b4019a5a0ba9b5d4aec79'
client_secret = '053a42ddc770464b8a046bd21095406e'

# %%
get_token(client_id,client_secret)
# Out:
# Token válido por 3600 segundos.
# 'BQD0gXqwdsJEbSwESsnH9KYhN7Qu2JzYHLSmR9nKW7e3UV9UilT8EFP0fCBZa2uyYYxxobD739jfnAIGOGQ'

# %%
header = {'Authorization':'Bearer {}'.format(token)}

# %%
id_paulo
# Out:
# '3vQ0GE3mI0dAaxIMYe5g7z'

# %%
ep_albums = '/artists/{artist_id}/albums'

# %%
url_base+ep_albums
# Out:
# 'https://api.spotify.com/v1/artists/{artist_id}/albums'

# %%
params = {'country':'AR'}

# %%
albums_paulo = requests.get(url_base+ep_albums.format(artist_id =id_paulo), headers=header, params=params)

# %%
albums_paulo.status_code
# Out:
# 200

# %%
album = albums_paulo.json()['items'][0]

# %%
lista_albums = [(album['id'], album['name']) for album in albums_paulo.json()['items']]
lista_albums
# Out:
# [('0qJkFmVwwNXP6fvSemDZqn', 'Homerun'),
#  ('2ce9XFj7OA3f78oO5XFFhV', 'Party (feat. A Boogie Wit da Hoodie)'),
#  ('0kHdDpkkSlesh2UMKhF20G', 'Nothing On You (feat. Paulo Londra & Dave)'),
#  ('5GcW2cCrVqjPm3dgDJOBRF',
#   'Solo Pienso En Ti (feat. De La Ghetto & Justin Quiles)'),
#  ('039RvHRSbMCfQLsYcg70BQ', 'Tal Vez'),
#  ('0vYYf2lqqXfCWXwhnjVDTZ', 'Forever Alone'),
#  ('1XBTyV1if5X9sU4IhpfH5R', 'Adan y Eva'),
#  ('66rMML0MqFyPkNgL3n98qQ', 'Condenado Para El Millón'),
#  ('1rNj1DvnXIH5irucrzT4zo', 'Cuando Te Besé'),
#  ('6SoJvyMGb8rWfwKjFlSTHX', 'Chica Paranormal'),
#  ('0H6WiJAgs0D0bH8ObA7xBc', 'Dímelo'),
#  ('0sF2dhoiBLVMvuv6qRIpYI', 'Te Amo'),
#  ('1RMkgNWPXhMF91oLAe2P7d', 'Nena Maldición (feat. Lenny Tavárez)'),
#  ('0GOrrE1p39WniF8QJGh3vT', 'Por Lo Mio'),
#  ('4vaKKTcbLjNconmQkPEoac', 'Cámara Lenta'),
#  ('2Z56yReoCsB0dFT35Wjozt', 'Luna Llena'),
#  ('2Uj19iREWnZV82vwaleycZ', 'Me Tiene Mal'),
#  ('7GhLiN2AD7DpssaAnMCZ3e', 'Confiado & Tranquilo'),
#  ('4iMobJpuYNhLPsVGDPStzb', 'Relax'),
#  ('5RBCpfPIJChW1a2SZ8oxk1', 'No Lo Vendo')]

# %%
album_ep = '/albums/{album_id}'
album_params = {'market':'AR'}

# %%
relax_id = '4iMobJpuYNhLPsVGDPStzb'

# %%
relax = requests.get(url_base+album_ep.format(album_id=relax_id)+'/tracks', headers=header, params=album_params)
relax
# Out:
# <Response [200]>

# %%
relax.json()['items']
# Out:
# [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3vQ0GE3mI0dAaxIMYe5g7z'},
#     'href': 'https://api.spotify.com/v1/artists/3vQ0GE3mI0dAaxIMYe5g7z',
#     'id': '3vQ0GE3mI0dAaxIMYe5g7z',
#     'name': 'Paulo Londra',
#     'type': 'artist',
#     'uri': 'spotify:artist:3vQ0GE3mI0dAaxIMYe5g7z'}],
#   'disc_number': 1,
#   'duration_ms': 233142,
#   'explicit': False,
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3lRdAB8pde348eiSc25Aq9'},
#   'href': 'https://api.spotify.com/v1/tracks/3lRdAB8pde348eiSc25Aq9',
#   'id': '3lRdAB8pde348eiSc25Aq9',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Relax',
#   'preview_url': 'https://p.scdn.co/mp3-preview/aa79551c14ee383291c1023e6f066ab8cb274587?cid=94324681d20b4019a5a0ba9b5d4aec79',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3lRdAB8pde348eiSc25Aq9'}]

# %%
[(track['id'], track['name']) for track in relax.json()['items']]
# Out:
# [('3lRdAB8pde348eiSc25Aq9', 'Relax')]

# %%
def obtener_discografia(artist_id, token, return_name = False, page_limit = 50, country = None):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    header = {'authorization': f'Bearer {token}'}
    params = {'limit' : page_limit, 
              'offset': 0, 
              'country': country}
    
    lista = []
    r = requests.get(url, params=params, headers=header)
    
    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        
        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
            
    return lista

# %%
def obtener_tracks(album_id, token, return_name = False, page_limit = 50, market=None):
    url = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    header = {'authorization': f'Bearer {token}'}
    params = {'limit' : page_limit, 
              'offset': 0, 
              'market': market}
    
    lista = []
    r = requests.get(url, params=params, headers=header)
    
    if r.status_code != 200:
        print('Error en la request.', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
        
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        
        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
            
    return lista

# %%
for album in obtener_discografia(id_paulo, token, return_name=True, country='AR'):
    print(album[1])
    for track in obtener_tracks(album[0], token, return_name= True, market='AR'):
        print('\t',track[1])
# Out:
# Homerun
# 	 Homerun (Intro)
# 	 Tal Vez
# 	 No Puedo
# 	 Adan y Eva
# 	 Demasiado Loco
# 	 Maldita Abusadora
# 	 Y Yo No Sé
# 	 So Fresh
# 	 Querido Amigo
# 	 Romeo y Julieta
# 	 Por Eso Vine
# 	 Solo Pienso En Ti (feat. De La Ghetto & Justin Quiles)
# 	 Forever Alone
# 	 Condenado Para El Millón
# 	 Nena Maldición (feat. Lenny Tavárez)
# 	 Dímelo
# 	 Chica Paranormal
# 	 Sigan Hablando de Mi
# Party (feat. A Boogie Wit da Hoodie)
# 	 Party (feat. A Boogie Wit da Hoodie)
# Nothing On You (feat. Paulo Londra & Dave)
# 	 Nothing On You (feat. Paulo Londra & Dave)
# Solo Pienso En Ti (feat. De La Ghetto & Justin Quiles)
# 	 Solo Pienso En Ti (feat. De La Ghetto & Justin Quiles)
# Tal Vez
# 	 Tal Vez
# Forever Alone
# 	 Forever Alone
# Adan y Eva
# 	 Adan y Eva
# Condenado Para El Millón
# 	 Condenado Para El Millón
# Cuando Te Besé
# 	 Cuando Te Besé
# Chica Paranormal
# 	 Chica Paranormal
# Dímelo
# 	 Dímelo
# Te Amo
# 	 Te Amo
# Nena Maldición (feat. Lenny Tavárez)
# 	 Nena Maldición (feat. Lenny Tavárez)
# Por Lo Mio
# 	 Por Lo Mio
# Cámara Lenta
# 	 Cámara Lenta
# Luna Llena
# 	 Luna Llena
# Me Tiene Mal
# 	 Me Tiene Mal
# Confiado & Tranquilo
# 	 Confiado & Tranquilo
# Relax
# 	 Relax
# No Lo Vendo
# 	 No Lo Vendo
# Tengo Fe
# 	 Tengo Fe
# INDUSA
# 	 Bobo
# 	 Negro Chetif
# 	 Burin
# 	 Mpunda
# 	 Du sal
# 	 Coup de point
# 	 Pas sans toi
# 	 the Cfa
# 	 Kitoko
# 	 KFGT
# Calm
# 	 Teka
# 	 Hype
# Rap Romantico 2
# 	 Todavía Te Quiero en Silencio
# 	 Me Vas a Extrañar
# 	 Serás Feliz Sin Mi
# 	 Quisiera No Haberte Conocido
# 	 Ese Fui Yo
# 	 Me Estoy Enamorando de Ti
# 	 Debo Olvidarte - Remasterizada
# 	 Lo Nuestro Acabó
# 	 Te Elegí a Ti
# 	 ¿Cómo Pude Enamorarme Así de Ti?
# 	 Para la Niña Que Me Gusta
# 	 14 de Febrero Sin Ti
# 	 Si Me Dices Que Si
# 	 Así Lo Decidiste - Remasterizada
# 	 Te Debo Soltar - Remasterizada
# 	 Carta para la Mejor Novia
# 	 Te Perdí
# 	 Te Darás Cuenta Tarde
# 	 Pensé Que Me Amabas - Remasterizada
# 	 Te Confundí Con el Amor de Mi Vida
# 	 Si Te Perdiera
# 	 Me Tengo Que Ir
# 	 Feliz 14 de Febrero
# 	 Nunca Quise Que Terminara
# 	 Siempre Juntos
# 	 No Debiste Ilusionarme - Remix
# 	 Gracias por un Mes Más
# 	 Un Mes
# 	 La Carta Más Triste
# 	 Derrites Mi Corazón
# 	 Somos Novios
# 	 Gracias a Ti
# 	 Cómo Tratarla - Remasterizada
# 	 Deja Que Sea Otro
# 	 Te Abandoné Sin Querer
# 	 Te Extraño
# 	 Pero Como Decirle
# 	 Solo Tú
# 	 Anda y Dile
# 	 Mi Niña Perfecta
# 	 Amor a Primera Vista
# 	 Si Ella Pregunta por Mi
# 	 Si Me Quedaba Contigo
# 	 Ahora Que No Estás
# 	 Tu Foto
# MALA SANTA
# 	 MALA SANTA
# 	 DOLLAR
# 	 24/7
# 	 SI SI
# 	 VÁMONOS
# 	 MEJOR ASÍ
# 	 PELEAS
# 	 NO TE PERTENEZCO
# 	 EN MI CONTRA
# 	 ME ACOSTUMBRÉ
# 	 NI DE TI NI DE NADIE
# 	 SUBIENDO
# 	 TE SUPERÉ
# 	 Cuando Te Besé
# 	 Sin Pijama
# 	 Mayores
# No.6 Collaborations Project
# 	 Beautiful People (feat. Khalid)
# 	 South of the Border (feat. Camila Cabello & Cardi B)
# 	 Cross Me (feat. Chance the Rapper & PnB Rock)
# 	 Take Me Back to London (feat. Stormzy)
# 	 Best Part of Me (feat. YEBBA)
# 	 I Don't Care (with Justin Bieber)
# 	 Antisocial (with Travis Scott)
# 	 Remember The Name (feat. Eminem & 50 Cent)
# 	 Feels (feat. Young Thug & J Hus)
# 	 Put It All on Me (feat. Ella Mai)
# 	 Nothing On You (feat. Paulo Londra & Dave)
# 	 I Don't Want Your Money (feat. H.E.R.)
# 	 1000 Nights (feat. Meek Mill & A Boogie Wit da Hoodie)
# 	 Way To Break My Heart (feat. Skrillex)
# 	 BLOW (with Chris Stapleton & Bruno Mars)
# No.6 Collaborations Project
# 	 Beautiful People (feat. Khalid)
# 	 South of the Border (feat. Camila Cabello & Cardi B)
# 	 Cross Me (feat. Chance the Rapper & PnB Rock)
# 	 Take Me Back to London (feat. Stormzy)
# 	 Best Part of Me (feat. YEBBA)
# 	 I Don't Care (with Justin Bieber)
# 	 Antisocial (with Travis Scott)
# 	 Remember The Name (feat. Eminem & 50 Cent)
# 	 Feels (feat. Young Thug & J Hus)
# 	 Put It All on Me (feat. Ella Mai)
# 	 Nothing On You (feat. Paulo Londra & Dave)
# 	 I Don't Want Your Money (feat. H.E.R.)
# 	 1000 Nights (feat. Meek Mill & A Boogie Wit da Hoodie)
# 	 Way To Break My Heart (feat. Skrillex)
# 	 BLOW (with Chris Stapleton & Bruno Mars)
# Ubuntu
# 	 La Vida Sin Ti
# 	 Te Amo (feat. Paulo Londra)
# 	 Besándote
# 	 Adrenalina (feat. Maikel Delacalle)
# 	 Frenesí (feat. Zion & Lennox)
# 	 Cada Noche
# 	 Tiempo
# 	 Déjala Que Vuelva (feat. Manuel Turizo)
# 	 Así No Se Hace
# 	 Puntos Suspensivos
# 	 Tu Héroe
# 	 Versos de Neruda (feat. Xantos, Fonseca)
# 	 Me Llamas
# Noche Complicada
# 	 Noche Complicada
# No la Puedo Olvidar
# 	 No la Puedo Olvidar
# Mvp
# 	 Mvp
# En Busca de Verdes
# 	 En Busca de Verdes
# Ni Aqui Ni de Alla (feat. paulo londra)
# 	 Ni Aqui Ni de Alla (feat. paulo londra)

# %%
preview_url = 'https://p.scdn.co/mp3-preview/aa79551c14ee383291c1023e6f066ab8cb274587?cid=94324681d20b4019a5a0ba9b5d4aec79'

# %%
preview = requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
import IPython.display as ipd

# %%
ipd.Audio(preview.content)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
